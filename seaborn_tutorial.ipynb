# %% [markdown]
# ![Seaborn Logo](https://seaborn.pydata.org/_images/logo-wide-lightbg.svg)
# # Seaborn Tutorial<br>

# %% [markdown]
# ## Supported Plots
# | Plot        | Example     |
# | ----------- | ----------- |
# | scattorplot | [link](https://seaborn.pydata.org/examples/different_scatter_variables.html) |
# | lineplot    | [link](https://seaborn.pydata.org/examples/errorband_lineplots.html) |
# | ...         | ... |

# %% [markdown]
# ## Line Chart
# This is a line chart created by given data.

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>
